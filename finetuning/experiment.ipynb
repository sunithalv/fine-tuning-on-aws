# %%
import boto3

# %%
s3=boto3.client("s3")

# %%
response=s3.list_objects_v2(Bucket="llm-finetune-dataset-sun",Prefix="datasets/")

# %%
for obj in response.get("Contents",[]):
    print(obj)
# Out:
# {'Key': 'datasets/', 'LastModified': datetime.datetime(2025, 12, 17, 16, 23, 27, tzinfo=tzlocal()), 'ETag': '"d41d8cd98f00b204e9800998ecf8427e"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 0, 'StorageClass': 'STANDARD'}

# %%
for obj in response.get("Contents",[]):
    print(obj["Key"])
# Out:
# datasets/
